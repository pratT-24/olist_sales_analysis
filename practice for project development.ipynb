# %%
# Example: Keep asking for input until the user enters "quit"
user_input = ""
while user_input != "quit":
    user_input = input("Enter something (or 'quit' to exit): ")
    print("You entered:", user_input)
# Out:
# You entered: quit

# %%
temperature = int(input("enter a number"))  # Let's assume the temperature is 15 degrees Celsius

if temperature < 10:
    print("Wear a jacket! It's cold out there.")
elif 10 <= temperature < 20:
    print("A light sweater should be fine. It's a bit chilly.")
elif 20 <= temperature < 30:
    print("Enjoy the pleasant weather! No need for extra layers.")
else:
    print("It's hot! Stay hydrated and wear sunscreen.")
# Out:
# It's hot! Stay hydrated and wear sunscreen.

# %%
numbers = [3, 9, 1, 10, 5, 2, 8]
for number in numbers:
    if number%2 ==0:
        print("even number:", number)
    else:
        print("odd number:", number)
# Out:
# odd number: 3
# odd number: 9
# odd number: 1
# even number: 10
# odd number: 5
# even number: 2
# even number: 8
