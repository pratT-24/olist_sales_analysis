# %%
import pandas

# %%
import os
import duckdb
import pandas as pd

# 1. Print current working directory
print("Current Project Folder:", os.getcwd())

# 2. Check if the 'data' folder actually exists right here
if os.path.exists("data"):
    print("📁 'data' folder found!")
    print("Files inside:", os.listdir("data"))
else:
    print("❌ ERROR: PyCharm cannot find the 'data' folder at this location.")
# Out:
# Current Project Folder: D:\Github projects\olist data
# ❌ ERROR: PyCharm cannot find the 'data' folder at this location.
